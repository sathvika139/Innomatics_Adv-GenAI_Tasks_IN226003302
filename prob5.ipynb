# %%
#program to monitor classroom resource usage and energy consumption
def monitor_classroom_resources(resource_usage):
    overused_resources = []
    for resource, hours in resource_usage.items():
        if hours > 8:   # Overuse threshold
            overused_resources.append(resource)
    if overused_resources:
        print("Overused Resources:", ", ".join(overused_resources))
        print("Energy Alert: Yes")
    else:
        print("Overused Resources: None")
        print("Energy Alert: No")

resource_usage = {
    "Projector": 6,
    "AC": 9,
    "Lights": 4
}
monitor_classroom_resources(resource_usage)
# Out:
# Overused Resources: AC
# Energy Alert: Yes
