# %%
# program to check inventory stock levels and alert for reordering
def check_inventory(stock_data):
    for product, quantity in stock_data.items():
        if quantity < 15:
            print(f"{product}: Reorder Alert (Stock = {quantity})")
        else:
            print(f"{product}: Stock OK (Stock = {quantity})")

inventory = {
    "Rice": 10,
    "Wheat": 25,
    "Sugar": 12,
    "Oil": 30,
    "Salt": 8
}
check_inventory(inventory)
# Out:
# Rice: Reorder Alert (Stock = 10)
# Wheat: Stock OK (Stock = 25)
# Sugar: Reorder Alert (Stock = 12)
# Oil: Stock OK (Stock = 30)
# Salt: Reorder Alert (Stock = 8)
